# %% [markdown]
# <a href="https://colab.research.google.com/github/WatanabeYohei/Programming/blob/IIM2024/Programming%EF%BC%95%E7%AB%A0%EF%BC%92%E7%AF%8020240826.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# p.131
# # 四則計算のプログラム
#
# Cでデータ処理を行うさいは，扱うデータに合った適切な**データ型**の利用や，データの入出力を行う必要がある。
#
# ---
# １　整数型データの取り扱い
#
# 例題１
# 二つの整数、a=45、b=1の和と差を求めるプログラムをつくりなさい。
# ```
# 01 /* 例題 1 */
# 02 #include<stdio.h>
# 03 int main(void)
# 04 {
# 05     int a, b, wa, sa;
# 06     a = 45;
# 07     b = 1;
# 08     wa = a ＋ b;
# 09     sa = a - b;
# 10     printf("a ＋ b = %d¥n", wa);
# 11     printf("a - b = %d¥n", sa);
# 12     return 0;
# 13 }
# ```
# 解説
#
# 行01　プログラムの注釈である。
#
# 行02　プリプロセッサ指令である。
#
# 行03 main 関数を定義する。
#
# 行04 main 関数のはじまりである。
#
# 行05　データの型宣言であり，4 個の変数を整数型で宣言する。
#
# 行06～07　変数a，b にデータを代入する。
#
# 行08～09　変数wa，sa に計算結果を代入する。
#
# 行10～11 printf 関数を用いて計算結果を出力する。
#
# 行12　システムにmain 関数の終了を知らせる。
#
# 行13 main 関数を終了する。

# %%
# %%file rei1.c
# // 例題１の内容を入力してみましょう。
# Out:
# Writing p131.c

# %%
//Ｃファイルの作成（上書き）ができたら、コンパイルして実行してみよう。
# !gcc rei1.c -o rei1 && ./rei1
# Out:
# ELIZABETH

# %% [markdown]
# pp.132-133
# #（基礎知識）
#
# Ａ　データ型：プログラム中で使用する変数は，変数名と扱うデータ型を宣言しておかなければならない。変数のデータ型を指定するのが型指定子であり，次の書式で記述する。
#
# ```
# 型指定子　変数1,変数2,変数3,……;
# 例 int  a,b,wa,sa;
# ```
# 表２に主な型指定子を示す。
#
#
# ![image.png](data:image/png;base64,...)
#
#
# Ｂ　変数：変数名は，英字ではじまり，2 文字目以降は，英字・数字・_（アンダスコア）を使うが，int，float などの予約語は変数名として使用できない。JIS では識別できる変数名の長さを規定していないが，一般的には先頭から31 文字までが変数として識別される。
#
#
# Ｃ　算術演算子：＋や－などのように演算を行うための記号を演算子という。演算子のうち，数値演算を行うものを算術演算子という。表3におもな算術演算子を示す。　演算子は，表4 に示すように，計算の優先順位が決まっている。計算の順番を変更するときは，優先順位の最も高い（　）を用いる。
#
#
# ![image.png](data:image/png;base64,...)
#
# Ｄ　printf関数：printf 関数はディスプレイにデータを出力する関数である。次の書式で記述する。
# ```
# printf(" 書式文字列",変数1,変数2,……）;
# 例 printf("a + b = %d \n", wa）;
# ```
# **書式文字列**は，入出力のための変換方法などを示す文字列である。変数がない場合は，書式文字列だけを記述すればよい。\nは１行改行を表す**拡張表記**とよばれる特殊記号である。%d は，データを**10進数**で出力させる記号であり，これを**変換指定子**という。表５に，おもな変換指定子を示す。
#
#
# ![image.png](data:image/png;base64,...)
#
#
# 練習問題１
#
# 三つの整数35，88，154 を変数a，b，c にそれぞれ代入して，a ＋ b ＋ c およびa － b － c を計算するプログラムをつくりなさい。
#
# ※自分でコード欄を追加して実行してみよう。
#
# %%file ren1.c
#
# !gcc ren1.c -o ren1 && ./ren1

# %% [markdown]
# p.134
# # ２実数型データの取り扱い
# 例題２
#
# 二つの実数a=52.6,b=78.4の積と商を求めるプログラムをつくりなさい。
# 答えは，小数点以下第２位まで出力すること。
#
# ![image.png](data:image/png;base64,...)
#
# 考え方
#
# 実数型変数a,b,seki,syou を宣言して、a とb に，それぞれ52.6 と78.4 を代入したのち，積と商を計算してseki，syou に代入する。
#
# ![image.png](data:image/png;base64,...)
#
# ```
# 01 /* 例題 2 */
# 02 #include〈stdio.h〉
# 03 int main(void)
# 04 {
# 05     float a, b, seki, syou;
# 06     a = 52.6;
# 07     b = 78.4;
# 08     seki = a * b;
# 09     syou = a / b;
# 10     printf("a * b = %7.2f¥n", seki);
# 11     printf("a / b = %7.2f¥n", syou);
# 12     return 0;
# 13 }
# ```
#
# 解説
#
# 行02　プリプロセッサ指令である。
#
# 行03 main 関数を定義する。
#
# 行04 main 関数のはじまりである。
#
# 行05 4 個の変数を実数型で宣言する。
#
# 行06～07　変数a，b にデータを代入する。
#
# 行08～09　変数seki，syou に計算結果を代入する。
#
# 行10～11 printf 関数により，変換指定子を用いて計算結果を全7 けた，小数点以下2 けたで出力する。
#
# 行13 main 関数を終了する。

# %%
# %%file rei2.c
# // 例題２の内容を入力してみましょう。

# %%
//Ｃファイルの作成（上書き）ができたら、コンパイルして実行してみよう。
# !gcc rei2.c -o rei2 && ./rei2

# %% [markdown]
# p.135
# # （基礎知識）
# Ａ　フィールド幅指定子：フィールド幅指定子とは，変換指定子とともに用いてデータの出力形式を指定するものである。表6 に，おもな
# フィールド幅指定子を示す。
#
# ![image.png](data:image/png;base64,...)
#
# 練習問題２
#
# 二つの実数35.2，85.4 を変数a，b にそれぞれ代入して，a2 ＋ b2 およびa2 － b2 を計算するプログラムをつくりなさい。
#
# ※自分でコード欄を追加して実行してみよう。
#
# %%file ren2.c
#
# !gcc ren2.c -o ren2 && ./ren2

# %% [markdown]
# p.136
# # 文字型データの取り扱い
#
# 例題３
# 文字型変数a，b，c に，それぞれＮ，Ｈ，3 を代入して出力し，さらにそれらの文字のJIS 文字コードを10 進数と16 進数で出力するプログラムをつくりなさい。
#
# ![image.png](data:image/png;base64,...)
#
# 考え方
#
# 文字型変数a，b，c を宣言して，それぞれN，H，3 を代入したのち，変換指定子を利用して出力する。
#
# ![image.png](data:image/png;base64,...)
#
# ```
# 01 /* 例題 3 */
# 02 #include〈stdio.h〉
# 03 int main(void)
# 04 {
# 05     char a, b, c;
# 06     a = ’N’;
# 07     b = ’H’;
# 08     c = ’3’;
# 09     printf("%c %c %c¥n", a, b, c);
# 10     printf("%d %d %d¥n", a, b, c);
# 11     printf("%x %x %x¥n", a, b, c);
# 12     return 0;
# 13 }
# ```
# 解説
#
# 行05　三つの変数を文字型で宣言する。
#
# 行06～08　変数a，b，c にデータを代入する。
#
# 行09　変数を文字として出力する。
#
# 行10　変数を10 進数で出力する。
#
# 行11　変数を16 進数で出力する。

# %%
# %%file rei3.c
# // 例題３の内容を入力してみましょう。

# %%
//Ｃファイルの作成（上書き）ができたら、コンパイルして実行してみよう。
# !gcc rei3.c -o rei3 && ./rei3

# %% [markdown]
# pp.136-137
# # （基礎知識）
# Ａ　JIS文字コード：コンピュータ内部では，文字をコード化して扱っている。JIS 文字コードを用いた文字には，2 進コードの8 ビット
# を用いる1 バイト文字と，16 ビットを用いる2 バイト文字がある。JIS 文字コードにおいて，1 バイト文字を16 進数で表現すると，N は4E，H は48，3 は33 となる。
# 　プログラムは，原則として1 バイト文字を使用して記述する必要がある。しかし，注釈などは2 バイト文字を使用することもできる。
#
# Ｂ　定数：値の決められた数値・文字のことを定数という。表7に，おもな定数を示す。なお，文字定数では1 バイト文字の使用を基本
# とするが，文字列リテラルでは1 バイト文字，2 バイト文字のどちらを使用してもよい。
#
# 練習問題３
#
# 文字型変数a，b，c，d にそれぞれT，a，r，o のJIS 文字コードを16 進数で代入したのち，それらを文字として出力するプログラムをつくりなさい。
#
# ※自分でコード欄を追加して実行してみよう。
#
# %%file ren3.c
#
# !gcc ren3.c -o ren3 && ./ren3

# %% [markdown]
# pp.137-138
# # キーボードからのデータ入力
#
# 例題４
#
# 二つの整数をキーボードから入力したとき，その和と差を計算して出力するプログラムをつくりなさい。
#
# ![image.png](data:image/png;base64,...)
#
# 考え方
#
# 整数型変数a，b を宣言し，scanf関数を用いてキーボードからデータを入力し，計算を行う。
#
# ![image.png](data:image/png;base64,...)
#
# ```
# 01 /* 例題 4 */
# 02 #include〈stdio.h〉
# 03 int main(void)
# 04 {
# 05     int a, b, wa, sa;
# 06     scanf("%d",&a);
# 07     scanf("%d",&b);
# 08     wa = a + b;
# 09     sa = a - b;
# 10     printf("a + b = %d¥n", wa);
# 11     printf("a - b = %d¥n", sa);
# 12     return 0;
# 13 }
# ```
#
# 解説
#
# 行05 4 個の変数を整数型で宣言する。
#
# 行06～07　キーボードからのデータを変数a，b に代入する。
#
# 行08～09　変数wa，sa に計算結果を代入する。
#
# 行10～11 printf 関数を用いて計算結果を出力する。

# %%
# %%file rei4.c
# // 例題４の内容を入力してみましょう。

# %%
//Ｃファイルの作成（上書き）ができたら、コンパイルして実行してみよう。
# !gcc rei4.c -o rei4 && ./rei4

# %% [markdown]
# p.138
# # （基礎知識）
#
# Ａ　scanf関数：scanf 関数はキーボードからデータを読み取る関数である。この関数は，次の書式で記述する。
# ```
# scanf("書式文字列",&変数1,&変数2,……);
# 例 scanf("%d",&a);
# ```
#
# scanf 関数では，変数名に& 記号をつけることになっている（図5）。
#
# ![image.png](data:image/png;base64,...)
#
# 練習問題４
#
# 1⃣二つの実数をキーボードから読み取り，その和・差・積・商を計算して出力するプログラムをつくりなさい。
#
# 2⃣三角形の3 辺の長さA，B，C を入力し，その面積S を求めるプログラムをつくりなさい。ただし，面積の計算はヘロンの公式を利用すること。
#
# ※自分でコード欄を追加して実行してみよう。
#
# %%file ren4_1.c
#
# !gcc ren4_1.c -o ren4_1 && ./ren4_1
#
# %%file ren4_2.c
#
# !gcc ren4_2.c -o ren4_2 && ./ren4_2
