# %% [markdown]
# <a href="https://colab.research.google.com/github/WatanabeYohei/Programming/blob/IIM2024/Programming%EF%BC%95%E7%AB%A0%EF%BC%95%E7%AF%8020240826.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ５章５節　配列
#
# 　配列を利用することで，多くの変数を宣言して使用することが不要となり，プログラムを簡潔に記述できるようになる。この節では，配列の宣言や使用方法について学ぶ。

# %% [markdown]
# p.153
# # １　一次元配列の利用
# 　関連のあるデータを1 列に並べた記憶領域に格納して扱うのが，**一次元配列**の考え方である。
#
# ---
#
# 例題12
#
# キーボードから入力した５個の整数データを配列に代入し，それらの合計を計算するプログラムをつくりなさい。
#
# ![image.png](data:image/png;base64,...)
#
# 考え方
#
# 配列要素を順次扱う場合には繰返
# し制御文を利用する。
#
# ![image.png](data:image/png;base64,...)
#
#
# ```
# 01 /* 例題 12 */
# 02 #include<stdio.h>
# 03 int main(void)
# 04 {
# 05     int i, s, a[5];
# 06     for(i = 0; i 〈 5; i++)
# 07         scanf("%d",&a[i]);
# 08     s = 0;
# 09     for(i = 0; i < 5; i++)
# 10         s = s + a[i];
# 11     printf("s = %d¥n", s);
# 12 return 0;
# 13 }
# ```
#
# 解説
#
# 行06～07　配列にデータを代入するループである。
#
# 行09～10　配列要素の合計を求めるループである。
#
# 行11　合計s を出力する。

# %%
# %%file rei12.c
# // 例題12の内容を入力してみましょう。

# %%
//Ｃファイルの作成（上書き）ができたら、コンパイルして実行してみよう。
# !gcc rei12.c -o rei12 && ./rei12

# %% [markdown]
# p.154
# #（基礎知識）
#
# Ａ　一次元配列：一次元配列の宣言は，次の書式で記述する。
#
# ```
# データ型 配列名[要素の個数];
#
# 例
# int a[5];
# ```
# この例では，a という名前の整数型配列が以下のように確保される。
#
# ![image.png](data:image/png;base64,...)
#
# 宣言時に指定したのは要素の個数であり，プログラム中で配列を使用する場合には，0 ～ 4（要素の個数－ 1）番の要素を扱うことにじゅうぶん注意すること。
#
# ---
#
# Ｂ　二次元配列：二次元配列の宣言は，次の書式で記述する。
#
# ```
# データ型　配列名[要素の個数][要素の個数];
#
# 例
# int b[3][4];
# ```
#
# 　この例では，b という名前の整数型配列が以下のように確保される。
#
# ![image.png](data:image/png;base64,...)
#
# ---
#
# 練習問題12
#
# 1⃣　キーボードから入力した5 個の実数型データを配列に代入し，それらの合計と平均を計算するプログラムをつくりなさい。（ren12_1）
#
# 2⃣　二次元配列に九九の値を代入して，それを出力するプログラムをつくりなさい。（ren12_2）
#
# ※自分でコード欄を追加して実行してみよう。
#
# %%file ren12_1.c
#
# !gcc ren12_1.c -o ren12_1 && ./ren12_1

# %% [markdown]
# pp.154-155
# # ２　データの検索
# ここでは，配列に格納した複数のデータのなかから，目的のデータ
# を探し出す検索プログラムについて学ぶ。
#
# ---
#
# 例題13
#
# 配列に5 個の整数データ786，386，831，23，865 を代入したあと，キーボードから入力したデータが配列内にある場合には，その
# 要素の番号を出力するプログラムをつくりなさい。
#
# ![image.png](data:image/png;base64,...)
#
# 考え方
#
# 目的のデータが配列内にあるかどうか，すべての要素について順次調べていく。
#
# ![image.png](data:image/png;base64,...)
#
#
# ```
# 01 /* 例題 13 */
# 02 #include<stdio.h>
# 03 int main(void)
# 04 {
# 05     int i, key;
# 06     int box[5] = {786,386,831,23,865};
# 07     scanf("%d",&key);
# 08     for(i = 0; i<5; i++){
# 09         if(box[i] == key)
# 10         printf("key = box[%d]¥n", i);
# 11     }
# 12 return 0;
# 13 }
# ```
#
# 解説
#
# 行06　整数型配列box の宣言と初期化である。
#
# 行07　検索するデータkey をキーボードから入力する。
#
# 行08～11　配列の要素を順次調べていくためのループである。
#
# 行09～10 key と同じデータがあれば，その要素の番号を出力する。

# %%
# %%file rei13.c
# // 例題13の内容を入力してみましょう。

# %%
//Ｃファイルの作成（上書き）ができたら、コンパイルして実行してみよう。
# !gcc rei13.c -o rei13 && ./rei13

# %% [markdown]
# p.155
# # （基礎知識）
# Ａ　配列の初期化：配列は，宣言時に初期化することができる。
#
# ```
# 例
# int box[5]={786,386,831,23,865};
# ```
#
# ![image.png](data:image/png;base64,...)
#
# ---
#
# 練習問題13
#
# 例題13 のプログラムを，データがなかった場合には「該当なし」と出力するプログラムに変更しなさい。
#
# ※自分でコード欄を追加して実行してみよう。
#
# %%file ren13.c
#
# !gcc ren13.c -o ren13 && ./ren13
