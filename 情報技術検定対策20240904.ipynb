# %% [markdown]
# <a href="https://colab.research.google.com/github/WatanabeYohei/Programming/blob/IIM2024/%E6%83%85%E5%A0%B1%E6%8A%80%E8%A1%93%E6%A4%9C%E5%AE%9A%E5%AF%BE%E7%AD%9620240904.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 第68回（令和４年度前期）

# %%
##問題の表示
from IPython.display import Image
Image(filename='/content/r4z_6.png')

# %%
# %%file r4z_6.c

# %%
# !gcc r4z_6.c -o r4z_6 && ./r4z_6

# %%
##問題の表示
from IPython.display import Image
Image(filename='/content/r4z_7.png')

# %%
# %%file r4z_7.c

# %%
# !gcc r4z_7.c -o r4z_7 && ./r4z_7

# %%
##問題の表示
from IPython.display import Image
Image(filename='/content/r4z_8.png')

# %%
# %%file r4z_8.c

# %%
# !gcc r4z_8.c -o r4z_8 && ./r4z_8

# %%
##問題の表示
from IPython.display import Image
Image(filename='/content/r4z_9.png')

# %%
# %%file r4z_9.c

# %%
# !gcc r4z_9.c -o r4z_9 && ./r4z_9

# %% [markdown]
# # 第69回（令和４年度後期）

# %%
##問題の表示
from IPython.display import Image
Image(filename='/content/r4k_6.png')

# %%
# %%file r4k_6.c

# %%
# !gcc r4k_6.c -o r4k_6 && ./r4k_6

# %%
##問題の表示
from IPython.display import Image
Image(filename='/content/r4k_7.png')

# %%
# %%file r4k_7.c

# %%
# !gcc r4k_7.c -o r4k_7 && ./r4k_7

# %%
##問題の表示
from IPython.display import Image
Image(filename='/content/r4k_8.png')

# %%
# %%file r4k_8.c

# %%
# !gcc r4k_8.c -o r4k_8 && ./r4k_8

# %%
##問題の表示
from IPython.display import Image
Image(filename='/content/r4k_9.png')

# %%
# %%file r4k_9.c

# %%
# !gcc r4k_9.c -o r4k_9 && ./r4k_9
